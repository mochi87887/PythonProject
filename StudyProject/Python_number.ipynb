# %% [markdown]
# # 教學網站:
# 1. https://ithelp.ithome.com.tw/articles/10315323
#
# # 參考資料:
# 1. https://steam.oxxostudio.tw/category/python/basic/number.html

# %% [markdown]
# # 整數
# 整數 integer，表示沒有分數或小數點的十進位數字，使用 type 查看整數的「型別」，可以得到「int」的型別。

# %%
type(87)
# Out:
# int

# %% [markdown]
# 整數的運算會產生小數點

# %%
type(3/2)
# Out:
# float

# %% [markdown]
# # 要讓一個數值等於「整數」，可以使用「int 函式」來進行型態的轉換

# %%
a = int(5.1)
b = int(9/2)
c = int('5')
d = int('+2')
e = int(True)
f = int(False)

print(a,b,c,d,e,f)
# Out:
# 5 4 5 2 1 0

# %% [markdown]
# # 二進制、八進制、十六進制的轉換
#
# *   十進制：0～9，當 10 的時候會進一位
# *   二進制：只有 1 和 0，當 2 的時候會進一位，變成 10，3 則是 11
# *   八進制：0～7，當 8 的時候會進一位，變成 10，9 則是 11
# *   十六進制：0～15 ( 10～15 由 A～F 表示 )，當 16 的時候會進一位，變成 10，11 則是 17

# %%
x = int('101', 2)
y = int('101', 8)
z = int('101', 16)
print(x,y,z)
# Out:
# 5 65 257

# %% [markdown]
# # 浮點數
# 表示包含小數點的十進位數字，使用 type 查看整數的「型別」，可以得到「float」的型別

# %%
type(6.9)
# Out:
# float

# %% [markdown]
# 使用浮點數和整數進行運算 ( 或和布林值運算 )，得到的結果會是浮點數

# %%
1.0 + 5
1.0 + True
1.0 + False
# Out:
# 1.0

# %% [markdown]
# # 浮點數可以透過「float 函式」將整數、數字文字或布林值，轉換成浮點數的數字

# %%
a = float(5)
b = float('5')
c = float('5.1')
d = float(True)
e = float(False)
print(a,b,c,d,e)
# Out:
# 5.0 5.0 5.1 1.0 0.0

# %% [markdown]
# # 底數
# 在數字的前方，加入 0b、0o 或 0x 的底數，來表示二進制、八進制或十六進制的數字

# %%
x = 0b1111 #( 二進制 )
y = 0o1111 #( 八進制 )
z = 0x1111 #( 十六進制 )
print(x,y,z)
# Out:
# 15 585 4369

# %% [markdown]
# # 布林
# 「布林 Bool」只有 True 和 False 兩個值，通常 True 可以表示為 1，Fasle 可以表示為 0

# %% [markdown]
# 「非 0 數字」會轉換為 True：

# %%
a = bool(True)
b = bool(1)
c = bool('ok')
d = bool(-1)
print(a,b,c,d)
# Out:
# True True True True

# %% [markdown]
# 「0 值數字」會轉換為 False：

# %%
x = bool(False)
y = bool(0)
z = bool(0.0)
print(x,y,z)
# Out:
# False False False
