# %% [markdown]
# # 教學網站:
# 1. https://ithelp.ithome.com.tw/articles/10315089
#
# # 參考資料:
# 1. https://steam.oxxostudio.tw/category/python/basic/and-or.html

# %% [markdown]
# # 在判斷式裡使用 and 和 or

# %%
a = 1
b = 2
c = 3

# 使用 and 必須前後條件都滿足
if a < b and a < c:
    print('here')

# 使用 or 只需要滿足其中一項
if a < b or a > c:
    print('there')
# Out:
# here
# there

# %%
# 如果有好幾個 or，越左方 ( 越前方 ) 會越先判斷，逐步往右邊判斷
a = 2
b = 3
c = 0

if a > b or a < c or a == 2:
    print('Ok1')
# Out:
# Ok1

# %%
# 如果同時有 and 和 or，則會先判斷 and，然後再接著從左向右判斷
a = 2
b = 3
c = 0

# 效果等同 (a>b or a<c) or (a==2 and b==4)
if a > b or a < c or a == 2 and b == 4:
    print('Ok1')
else:
    print('OK2')
# Out:
# OK2

# %% [markdown]
# # 使用 and 和 or 回傳值

# %%
a = 1 and 2 and 3
print(a)            # 3，全部都 True，所以回傳最右邊的值

b = 1 and 0 and 2
print(b)            # 0，遇到 0 ( False )，回傳第一個 False 的值就是 0

c = 1 or 2 or 3
print(c)            # 1，全部都 True，所以回傳第一個值

d = 1 or 0 or 3
print(d)            # 1，遇到 0 ( False )，回傳第一個 True 的值就是 1

e = 1 and 2 or 3
print(e)            # 2，效果等同 1 and ( 2 or 3 )

f = 1 or 2 and 3
print(f)            # 1，效果等同 1 or ( 2 and 3 )，2 和 3 先取出 3 之後變成 1 or 3

g = 1 and 2 or 3 and 4 or 5
print(g)            # 2，效果等同 1 and ( 2 or ( 3 and ( 4 or 5 )))
# Out:
# 3
# 0
# 1
# 1
# 2
# 1
# 2

# %%
a = 1
b = 2
c = 3

if(a and b and c):
    print('OK')
# Out:
# OK

# %%
a = 1
b = 0
c = 3

if(a and b and c):
    print('ok')
else:
    print('Not OK')
# Out:
# Not OK
